# %%
import pandas as pd
import os
import glob

# %%
files = glob.glob(os.path.join("./test_data/Route15", "*.csv"))

# %%
df = pd.concat((pd.read_csv(f, header=0) for f in files), axis=1)

# %%
df
# Out:
#          Speed    Time     Grade      Distance
# 0     0.000000     1.0  0.093175      0.000000
# 1     0.000000     2.0  0.093081      0.109253
# 2     0.000000     3.0  0.092987      0.218506
# 3     0.000000     4.0  0.092893      0.327759
# 4     0.000000     5.0  0.092800      0.437012
# ...        ...     ...       ...           ...
# 2712  5.833317  2713.0 -0.796225  12922.866247
# 2713  5.555540  2714.0 -0.320600  12928.295895
# 2714  4.999986  2715.0  0.080246  12933.725544
# 2715  3.888878  2716.0  0.382375  12939.155192
# 2716  1.944439  2717.0  0.530873  12940.964333
#
# [2717 rows x 4 columns]

# %%
df.plot(x = 'Time', y = 'Speed')
# Out:
# <Axes: xlabel='Time'>

# %%
df.plot(x = 'Distance', y = 'Speed')
# Out:
# <Axes: xlabel='Distance'>

# %%
df.plot(x = 'Distance', y = 'Grade')
# Out:
# <Axes: xlabel='Distance'>

# %%
df.plot(x = 'Time', y = 'Distance')
# Out:
# <Axes: xlabel='Time'>
